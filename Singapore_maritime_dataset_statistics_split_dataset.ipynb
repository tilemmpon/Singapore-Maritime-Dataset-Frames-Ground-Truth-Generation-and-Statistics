# %% [markdown]
# # Data statistics of the Singapore maritime dataset for the split data
#
# This is a jupyter notebook to calculate some statistics of the Singapore maritime dataset as it was split into training and test datasets for every 5 frames.
#
# Dataset available here: https://sites.google.com/site/dilipprasad/home/singapore-maritime-dataset
#
# If this dataset is used please cite it as:
#
# D. K. Prasad, D. Rajan, L. Rachmawati, E. Rajabaly, and C. Quek, "Video Processing from Electro-optical Sensors for Object Detection and Tracking in Maritime Environment: A Survey," IEEE Transactions on Intelligent Transportation Systems (IEEE), 2017.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
import colorsys
import pandas as pd
import os

# %% [markdown]
# Get the frames that exist in both training and test dataset folders.

# %%
SEPARATE_FOLDERS = False # there are separate folders under train/test or all images are in train/test dirs

TRAIN_PATH = './train'
TEST_PATH = './test'

if SEPARATE_FOLDERS:
    train_folders = [os.path.join(TRAIN_PATH, directory) for directory in os.listdir(TRAIN_PATH) 
                           if os.path.isdir(os.path.join(TRAIN_PATH, directory))]
    test_folders = [os.path.join(TEST_PATH, directory) for directory in os.listdir(TEST_PATH) 
                           if os.path.isdir(os.path.join(TEST_PATH, directory))]

    train_frames = []
    for folder in train_folders:
        train_frames = train_frames + [os.path.join(folder, f) for f in os.listdir(folder)
                           if os.path.isfile(os.path.join(folder, f))]

    test_frames = []
    for folder in test_folders:
        test_frames = test_frames + [os.path.join(folder, f) for f in os.listdir(folder)
                           if os.path.isfile(os.path.join(folder, f))]
        
else:
    train_frames = [os.path.join(TRAIN_PATH, f) for f in os.listdir(TRAIN_PATH)
                       if os.path.isfile(os.path.join(TRAIN_PATH, f))]

    test_frames = [os.path.join(TEST_PATH, f) for f in os.listdir(TEST_PATH)
                       if os.path.isfile(os.path.join(TEST_PATH, f))]

    
total_frames = len(train_frames) + len(test_frames)
print("Total number of training frames is %d and represent %f of total frames." 
                      % (len(train_frames), len(train_frames) / total_frames))
print("Total number of test frames is %d and represent %f of total frames." 
                      % (len(test_frames), len(test_frames) /total_frames))
# Out:
# Total number of training frames is 5157 and represent 0.703643 of total frames.
# Total number of test frames is 2172 and represent 0.296357 of total frames.

# %% [markdown]
# First lets load the object ground truth from the pre-calculated text files.

# %%
objects_onshore = []
with open("objects_onshore.txt") as f:
    for line in f: 
        line = line.strip()
        objects_onshore.append(line)
        
objects_onboard = []
with open("objects_onboard.txt") as f:
    for line in f: 
        line = line.strip()
        objects_onboard.append(line)
        
objects_nir = []
with open("objects_nir.txt") as f:
    for line in f: 
        line = line.strip()
        objects_nir.append(line)
        
print("Example entry of ground truth files:")
print(objects_onboard[0])
# Out:
# Example entry of ground truth files:
# MVI_0797_VIS_OB_frame0.jpg,1327.534834324554,459.75233644859804,161.49532710280369,42.412914188615105,3,2,1

# %% [markdown]
# The form of each line/entry is:
#
# [video_name] _ [frame_number] ,minimum x, minimum y, object width, object height, type of object, distance of object, type of motion of object
#
# Further description can be found here (https://drive.google.com/file/d/0B10RxHxW3I92NjRjZnN1bjVjelk/view).
#
# We only need to keep entries that are rellevant to the frames we use for training and testing. Let's select these entries.

# %%
# This is TOO slow!! Run next cell instead

object_list_full = objects_onshore + objects_onboard + objects_nir

train_objects = []
for file in train_frames:
    name = file.split('/')[-1]
    
    for entry in object_list_full:
        entry_filename = entry.split(',')[0]
        if entry_filename == name:
            train_objects.append(entry)
                
print(train_objects)

# %%
object_list_full = objects_onshore + objects_onboard + objects_nir

train_filenames = []
for file in train_frames:
    train_filenames.append(file.split('/')[-1])

train_objects = []
for entry in object_list_full:
    entry_filename = entry.split(',')[0]
    if entry_filename in train_filenames:
        train_objects.append(entry)
    
                
test_filenames = []
for file in test_frames:
    test_filenames.append(file.split('/')[-1])
    
test_objects = []
for entry in object_list_full:
    entry_filename = entry.split(',')[0]
    if entry_filename in test_filenames:
        test_objects.append(entry)

# %%
print('Number of objects in train dataset frames: %d' % len(train_objects))
print('Number of objects in test dataset frames: %d' % len(test_objects))
# Out:
# Number of objects in train dataset frames: 34376
# Number of objects in test dataset frames: 13941

# %% [markdown]
# # Dictionaries for the object type, motion and dictance.
#
# Now lets create the dictionaries for the object type, motion and dictance and unique colours for each of them.

# %%
def colors(n):
    """
    code from: https://www.quora.com/How-do-I-generate-n-visually-distinct-RGB-colours-in-Python
    """
    ret = []
    r = int(random.random() * 256)
    g = int(random.random() * 256)
    b = int(random.random() * 256)
    step = 256 / n
    for i in range(n):
        r += step
        g += step
        b += step
        r = int(r) % 256
        g = int(g) % 256
        b = int(b) % 256
        ret.append((r,g,b)) 
    return ret

def get_colors(num_colors):
    colors=[]
    for i in np.arange(0., 360., 360. / num_colors):
        hue = i/360.
        lightness = (50 + np.random.rand() * 10)/100.
        saturation = (90 + np.random.rand() * 10)/100.
        colors.append(colorsys.hls_to_rgb(hue, lightness, saturation))
    return colors

# %%
object_type_dict = {
    1:'Ferry',
    2:'Buoy',
    3:'Vessel/ship',
    4:'Speed boat',
    5:'Boat',
    6:'Kayak',
    7:'Sail boat',
    8:'Swimming person',
    9:'Flying bid/plane',
    10:'Other'
}

object_motion_dict = {
    1:'Moving',
    2:'Stationary',
    3:'Other'
}

object_distance_dict = {
    1:'Near',
    2:'Far',
    3:'Other'
}

object_colours_list = get_colors(len(object_type_dict))

# %% [markdown]
# # Generate object size histograms for the train and test datasets

# %%
FIGURE_SAVE_PATH = './figures_split'

# %%
# the dimensions of the images are predefined to 1920*1080
image_height = 1080
image_width = 1920

number_of_objects_train = len(train_objects) # 34376
number_of_objects_test = len(test_objects) # 13941

obj_height_train = np.zeros([number_of_objects_train])
obj_width_train = np.zeros([number_of_objects_train])
obj_area_train = np.zeros([number_of_objects_train])

obj_height_test = np.zeros([number_of_objects_test])
obj_width_test = np.zeros([number_of_objects_test])
obj_area_test = np.zeros([number_of_objects_test])

# %%
for i, obj in enumerate(train_objects):
    data = obj.split(',')
    obj_width_train[i] = float(data[3])
    obj_height_train[i] = float(data[4])
    
obj_area_train = obj_width_train * obj_height_train

for i, obj in enumerate(test_objects):
    data = obj.split(',')
    obj_width_test[i] = float(data[3])
    obj_height_test[i] = float(data[4])
    
obj_area_test = obj_width_test * obj_height_test

# %%
# scale them based on the image size
obj_width_ratio_train = obj_width_train.copy() / image_width
obj_height_ratio_train = obj_height_train.copy() / image_height
obj_area_ratio_train = obj_area_train.copy() / (image_height * image_width)

obj_width_ratio_test = obj_width_test.copy() / image_width
obj_height_ratio_test = obj_height_test.copy() / image_height
obj_area_ratio_test = obj_area_test.copy() / (image_height * image_width)

# %%
plt.hist(obj_area_ratio_train, bins=100)  # arguments are passed to np.histogram
plt.title("Histogram of train objects bounding box area ratios")
plt.ylabel("frequency")
plt.xlabel("percentage of total image covered")
plt.grid()
plt.savefig(os.path.join(FIGURE_SAVE_PATH, "histogram_area_train.jpg"), tight_layout=True, dpi=300)
plt.show()

plt.hist(obj_height_ratio_train, bins=100)  # arguments are passed to np.histogram
plt.title("Histogram of train objects bounding box height ratios")
plt.ylabel("frequency")
plt.xlabel("percentage of image height")
plt.grid()
plt.savefig(os.path.join(FIGURE_SAVE_PATH, "histogram_height_train.jpg"), tight_layout=True, dpi=300)
plt.show()

plt.hist(obj_width_ratio_train, bins=100)  # arguments are passed to np.histogram
plt.title("Histogram of train objects bounding box height ratios")
plt.ylabel("frequency")
plt.xlabel("percentage of image width")
plt.grid()
plt.savefig(os.path.join(FIGURE_SAVE_PATH, "histogram_width_train.jpg"), tight_layout=True, dpi=300)
plt.show()

# %%
plt.hist(obj_area_ratio_test, bins=100)  # arguments are passed to np.histogram
plt.title("Histogram of test objects bounding box area ratios")
plt.ylabel("frequency")
plt.xlabel("percentage of total image covered")
plt.grid()
plt.savefig(os.path.join(FIGURE_SAVE_PATH, "histogram_area_test.jpg"), tight_layout=True, dpi=300)
plt.show()

plt.hist(obj_height_ratio_test, bins=100)  # arguments are passed to np.histogram
plt.title("Histogram of test objects bounding box height ratios")
plt.ylabel("frequency")
plt.xlabel("percentage of image height")
plt.grid()
plt.savefig(os.path.join(FIGURE_SAVE_PATH, "histogram_height_test.jpg"), tight_layout=True, dpi=300)
plt.show()

plt.hist(obj_width_ratio_test, bins=100)  # arguments are passed to np.histogram
plt.title("Histogram of test objects bounding box height ratios")
plt.ylabel("frequency")
plt.xlabel("percentage of image width")
plt.grid()
plt.savefig(os.path.join(FIGURE_SAVE_PATH, "histogram_width_test.jpg"), tight_layout=True, dpi=300)
plt.show()

# %% [markdown]
# # Frequency and ratio of objects' type/motion/distance in the datasets
#
# Calculate the frequency and ratio of objects in the dataset and generate appropriate graphs.

# %%
number_of_objects_train = len(train_objects)
number_of_objects_test = len(test_objects)

# create empty numpy arrays to accommodate all relevant data
objects_type_train = np.empty([number_of_objects_train])
objects_type_test = np.empty([number_of_objects_test])

objects_motion_train = np.empty([number_of_objects_train])
objects_motion_test = np.empty([number_of_objects_test])

objects_distance_train = np.empty([number_of_objects_train])
objects_distance_test = np.empty([number_of_objects_test])

# %%
# iterate and gather relevant data
for i, obj in enumerate(train_objects):
    data = obj.split(',')
    objects_type_train[i] = int(data[5])
    objects_motion_train[i] = int(data[6])
    objects_distance_train[i] = int(data[7])
    
for i, obj in enumerate(test_objects):
    data = obj.split(',')
    objects_type_test[i] = int(data[5])
    objects_motion_test[i] = int(data[6])
    objects_distance_test[i] = int(data[7])

# %% [markdown]
# lets generate the relevant data for all dataset

# %%
objects_type_total = np.vstack((objects_type_train[:,np.newaxis], objects_type_test[:,np.newaxis]))

objects_distance_total = np.vstack((objects_distance_train[:,np.newaxis], objects_distance_test[:,np.newaxis]))

objects_motion_total = np.vstack((objects_motion_train[:,np.newaxis], objects_motion_test[:,np.newaxis]))

# %%
unique, counts = np.unique(objects_type_train, return_counts=True)

print(np.asarray((unique, counts)).T)
# Out:
# [[1.0000e+00 1.4820e+03]
#  [2.0000e+00 5.3100e+02]
#  [3.0000e+00 2.4746e+04]
#  [4.0000e+00 1.4690e+03]
#  [5.0000e+00 2.2600e+02]
#  [6.0000e+00 6.3300e+02]
#  [7.0000e+00 4.3300e+02]
#  [9.0000e+00 1.3200e+02]
#  [1.0000e+01 4.7240e+03]]

# %%
def generate_unique_values_histogram(x):
    """
    Helper function to count unique entries in an array and each entry's count.
    """
    unique, counts = np.unique(x, return_counts=True)
    return unique, counts

# %% [markdown]
# # Charts of object type/motion/distance frequency in the train/test datasets
#
# In this section the frequencies of the objects' type, motion and distance will be given in nice graphs

# %%
def autolabel(ax, rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

# %%
# Example plot

train_object_type_values, train_object_type_counts = generate_unique_values_histogram(objects_type_train)
 
objects_labels = []
for i in train_object_type_values:
    objects_labels.append(object_type_dict[int(i)])

y_pos = np.arange(len(objects_labels))
#performance = [10,8,6,4,2,1]
 
rects = plt.bar(y_pos, train_object_type_counts, align='center', alpha=0.5)
plt.xticks(y_pos, objects_labels, rotation='vertical')
plt.ylabel('frequency')
plt.title('Frequency of objects in train dataset')

autolabel(plt, rects)
plt.ylim(top=plt.ylim()[1]+5000)
 
plt.show()

# %%
def draw_bar_chart(x, x_dict, title, file_name='', vertical_x_labels=False):
    """
    This function generates a bar chart for the Singapore Maritime Dataset based on the paramaters given.
    
    Parameters
    ----------
    
    x : the data to be used. It is a 1d numpy array with integer values.
    
    x_dict : the dictionary with the corresponding string values of the x.
                example: x_dict[x[0]] = 'corresponding string for value in x[0]'
    
    title: title of the chart. (string)
    
    file_name : the filename to save the figure. If left as empty string the figure will no be saved. 
                Default: empty string.
    
    vertical_x_labels : should the xticks labels be drawn vertical? (boolean)
                Default: False
    """
    values, counts = generate_unique_values_histogram(x)
    
    labels = []
    for i in values:
        labels.append(x_dict[int(i)])

    y_pos = np.arange(len(labels))

    plt.figure()
    plt.bar(y_pos, counts, align='center', alpha=0.5)
    if vertical_x_labels:
        plt.xticks(y_pos, labels, rotation='vertical')
    else:
        plt.xticks(y_pos, labels)
    plt.ylabel('frequency')
    plt.title(title)
    
    if file_name != '':
        plt.savefig(file_name)
    plt.show()

# %%
def draw_bar_chart_subplot(ax, x, x_dict, title, vertical_x_labels=False, colour_list=None):
    """
    This function generates a bar chart for the Singapore Maritime Dataset based on the paramaters given.
    
    Parameters
    ----------
    
    ax : matplotlib.axes.Axes object.
    
    x : the data to be used. It is a 1d numpy array with integer values.
    
    x_dict : the dictionary with the corresponding string values of the x.
                example: x_dict[x[0]] = 'corresponding string for value in x[0]'
    
    title: title of the chart. (string)
    
    vertical_x_labels : should the xticks labels be drawn vertical? (boolean)
                Default: False
                
    colour_list : a list with colour for each x (unique) value. If set to None then all bars will be blue.
                Default: None
    """
    values, counts = generate_unique_values_histogram(x)
    
    labels = []
    for i in values:
        labels.append(x_dict[int(i)])

    y_pos = np.arange(len(labels))
    
    barlist = ax.bar(y_pos, counts, align='center', alpha=0.5)
    
    if colour_list is not None:
        # set colours
        for i, value in enumerate(values):
            barlist[i].set_color(colour_list[int(value-1)])
    
    autolabel(ax, barlist)
    ax.set_ylim(top=ax.get_ylim()[1]+9000)
    
    if vertical_x_labels:
        ax.set_xticks(y_pos)
        ax.set_xticklabels(labels, rotation='vertical')
    else:
        ax.set_xticks(y_pos)
        ax.set_xticklabels(labels)
    ax.set_ylabel('frequency')
    ax.set_title(title)

# %%
fig, ax = plt.subplots(nrows=3, ncols=3)
fig.set_size_inches(15.5, 8.5)
plt.tight_layout()

plt.subplots_adjust(top=0.85) # to include title on TOP of figure. Otherwise it overlaps due to tight_layout

fig.subplots_adjust(wspace=0.3,hspace=1.9)

draw_bar_chart_subplot(ax[0,0], objects_type_train, object_type_dict, 'Frequency of objects in train dataset', True, object_colours_list)
draw_bar_chart_subplot(ax[0,1], objects_type_test, object_type_dict, 'Frequency of objects in test dataset', True, object_colours_list)
draw_bar_chart_subplot(ax[0,2], objects_type_total, object_type_dict, 'Frequency of objects in train+test dataset', True, object_colours_list)

#TODO: remove colorlist arguments from these??
draw_bar_chart_subplot(ax[1,0], objects_motion_train, object_motion_dict, "Frequency of objects' motion in train dataset", False, object_colours_list)
draw_bar_chart_subplot(ax[1,1], objects_motion_test, object_motion_dict, "Frequency of objects' motion in test dataset", False, object_colours_list)
draw_bar_chart_subplot(ax[1,2], objects_motion_total, object_motion_dict, "Frequency of objects' motion in train+test dataset", False, object_colours_list)

draw_bar_chart_subplot(ax[2,0], objects_distance_train, object_distance_dict, "Frequency of objects' distance in train dataset", False, object_colours_list)
draw_bar_chart_subplot(ax[2,1], objects_distance_test, object_distance_dict, "Frequency of objects' distance in test dataset", False, object_colours_list)
draw_bar_chart_subplot(ax[2,2], objects_distance_total, object_distance_dict, "Frequency of objects' distance in train+test dataset", False, object_colours_list)

fig.suptitle("Frequencies of objects' types,motion and distance for train, test and the combined dataset", fontsize=16)

plt.savefig(os.path.join(FIGURE_SAVE_PATH, 'multiple_graphs.png'), bbox_inches='tight', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(nrows=3, ncols=1)
fig.set_size_inches(5.5, 6.5)
plt.tight_layout()

plt.subplots_adjust(top=0.85) # to include title on TOP of figure. Otherwise it overlaps due to tight_layout

fig.subplots_adjust(wspace=0.3,hspace=1.9)

draw_bar_chart_subplot(ax[0], objects_type_train, object_type_dict, 'Frequency of objects in train dataset', True, object_colours_list)
draw_bar_chart_subplot(ax[1], objects_type_test, object_type_dict, 'Frequency of objects in test dataset', True, object_colours_list)
draw_bar_chart_subplot(ax[2], objects_type_total, object_type_dict, 'Frequency of objects in train+test dataset', True, object_colours_list)


fig.suptitle("Frequencies of objects' types for train, test and the combined dataset", fontsize=16)

plt.savefig(os.path.join(FIGURE_SAVE_PATH, 'multiple_graphs_types.png'), bbox_inches='tight', dpi=300)
plt.show()

# %%
draw_bar_chart(objects_type_onshore, object_type_dict, 'Frequency of objects in Singapore onshore dataset','',True)

# %%
draw_bar_chart(objects_type_onboard, object_type_dict, 'Frequency of objects in Singapore onboard dataset','',True)

# %%
draw_bar_chart(objects_motion_onshore, object_motion_dict, "Frequency of objects' motion in Singapore onshore dataset")

# %%
draw_bar_chart(objects_motion_onboard, object_motion_dict, "Frequency of objects' motion in Singapore onboard dataset")

# %%
draw_bar_chart(objects_distance_onshore, object_distance_dict, "Frequency of objects' distance in Singapore onshore dataset")

# %%
draw_bar_chart(objects_distance_onboard, object_distance_dict, "Frequency of objects' distance in Singapore onboard dataset")

# %% [markdown]
# Lets merge the two datasets and output statistics for the whole dataset of images.

# %%
objects_type_total = np.vstack((objects_type_onshore[:,np.newaxis], objects_type_onboard[:,np.newaxis]))
objects_distance_total = np.vstack((objects_distance_onshore[:,np.newaxis], objects_distance_onboard[:,np.newaxis]))
objects_motion_total = np.vstack((objects_motion_onshore[:,np.newaxis], objects_motion_onboard[:,np.newaxis]))

# %%
draw_bar_chart(objects_type_total, object_type_dict, 'Frequency of objects in Singapore onshore+onboard dataset','',True)

# %%
draw_bar_chart(objects_motion_total, object_motion_dict, "Frequency of objects' motion in Singapore onshore6+onboard dataset")

# %%
draw_bar_chart(objects_distance_total, object_distance_dict, "Frequency of objects' distance in Singapore onshore+onboard dataset")

# %% [markdown]
# # Multi-bar plot for motion and distance of objects

# %%
N = 3 # we have three motion types

ind = np.arange(N)  # the x locations for the groups
width = 0.25       # the width of the bars

values, counts = generate_unique_values_histogram(objects_motion_train)

fig, ax = plt.subplots()
rects1 = ax.bar(ind, counts, width, color='r')

values, counts = generate_unique_values_histogram(objects_motion_test)
rects2 = ax.bar(ind + width, counts, width, color='b')

# add some text for labels, title and axes ticks
ax.set_ylabel('Frequency')
#ax.set_xlabel('Movement of objects')
ax.set_title('Motion of objects by type and dataset')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((object_motion_dict[1], object_motion_dict[2], object_motion_dict[3]))

ax.legend((rects1[0], rects2[0]), ('train', 'test'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

#plt.tight_layout()
#plt.ylim(top=20000)
ax.set_ylim(top=35000)

plt.savefig(os.path.join(FIGURE_SAVE_PATH, 'object_motion_multibar.png'), bbox_inches='tight',dpi=300)
plt.show()

# %%
N = 2 # we have two dataset sources (train/test)

ind = np.arange(N)  # the x locations for the groups
width = 0.25       # the width of the bars

values, counts_train = generate_unique_values_histogram(objects_motion_train)
values, counts_test = generate_unique_values_histogram(objects_motion_test)

fig, ax = plt.subplots()
rects1 = ax.bar(ind, (counts_train[0], counts_test[0]), width, color='r')

rects2 = ax.bar(ind + width, (counts_train[1], counts_test[1]), width, color='b')

rects3 = ax.bar(ind + 2* width, (counts_train[2], counts_test[2]), width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Frequency')
#ax.set_xlabel('Movement of objects')
ax.set_title('Motion of objects by type and dataset')
ax.set_xticks(ind + width)
#ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('train', 'test'))

ax.legend((rects1[0], rects2[0], rects3[0]), (object_motion_dict[1], object_motion_dict[2], object_motion_dict[3]))

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

#plt.tight_layout()
#plt.ylim(top=20000)
ax.set_ylim(top=35000)

plt.savefig(os.path.join(FIGURE_SAVE_PATH, 'object_motion_multibar_2.png'), bbox_inches='tight',dpi=300)
plt.show()

# %%
def pad_missing_counts(counts):
    """
    Helper function to add missing zero entries for "other" type
    """
    if len(counts) < 3:
        counts = np.vstack([counts[:, np.newaxis],np.array([0])])[:,0]
        
    return counts

# %%
N = 3 # we have three distance types

ind = np.arange(N)  # the x locations for the groups
width = 0.25       # the width of the bars

values, counts = generate_unique_values_histogram(objects_distance_train)
counts = pad_missing_counts(counts)
fig, ax = plt.subplots()
rects1 = ax.bar(ind, counts, width, color='r')

values, counts = generate_unique_values_histogram(objects_distance_test)
counts = pad_missing_counts(counts)
rects2 = ax.bar(ind + width, counts, width, color='b')

#values, counts = generate_unique_values_histogram(objects_distance_nir)
#counts = pad_missing_counts(counts)
#rects3 = ax.bar(ind + 2 * width, counts, width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Frequency')
#ax.set_xlabel('Movement of objects')
ax.set_title('Distance of objects by type and dataset')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((object_distance_dict[1], object_distance_dict[2], object_distance_dict[3]))

ax.legend((rects1[0], rects2[0]), ('train', 'test'))

autolabel(rects1)
autolabel(rects2)
#autolabel(rects3)

#plt.tight_layout()
#plt.ylim(top=20000)
ax.set_ylim(top=35000)

plt.savefig(os.path.join(FIGURE_SAVE_PATH, 'object_distance_multibar.png'), bbox_inches='tight',dpi=300)
plt.show()

# %%
N = 2 # we have two datasets (train/test)

ind = np.arange(N)  # the x locations for the groups
width = 0.25       # the width of the bars

values, counts_train = generate_unique_values_histogram(objects_distance_train)
counts_train = pad_missing_counts(counts_train)
values, counts_test = generate_unique_values_histogram(objects_distance_test)
counts_test = pad_missing_counts(counts_test)

fig, ax = plt.subplots()
rects1 = ax.bar(ind, (counts_train[0], counts_test[0]), width, color='r')

rects2 = ax.bar(ind + width, (counts_train[1], counts_test[1]), width, color='b')

rects3 = ax.bar(ind + 2 * width, (counts_train[2], counts_test[2]), width, color='y')

# add some text for labels, title and axes ticks
ax.set_ylabel('Frequency')
#ax.set_xlabel('Movement of objects')
ax.set_title('Distance of objects by type and dataset')
ax.set_xticks(ind + width)
#ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('train', 'test'))

ax.legend((rects1[0], rects2[0], rects3[0]), (object_distance_dict[1], object_distance_dict[2], object_distance_dict[3]))

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

#plt.tight_layout()
#plt.ylim(top=20000)
ax.set_ylim(top=35000)

plt.savefig(os.path.join(FIGURE_SAVE_PATH, 'object_distance_multibar_2.png'), bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# # Statistics per video
#
# generate statistic for every video in order to see how the objects are spread

# %%
# first on shore videos!
# first get all unique videos from the ground truth files and their 
# corresponding frame numbers. Create a dictionary in the form: <video_name>:<frame_count>

unique_videos = {}
for line in train_objects:
    video_name = line.split(',')[0].split('_')[:-1]
    video_name = '_'.join(video_name)
    
    if video_name not in unique_videos:
        unique_videos[video_name] = 1
    else:
        unique_videos[video_name] += 1
        
print(unique_videos)
# Out:
# {'MVI_1624_VIS': 280, 'MVI_1587_VIS': 1247, 'MVI_1584_VIS': 988, 'MVI_1645_VIS': 450, 'MVI_1619_VIS': 402, 'MVI_1622_VIS': 162, 'MVI_1620_VIS': 426, 'MVI_1627_VIS': 595, 'MVI_1640_VIS': 308, 'MVI_1583_VIS': 467, 'MVI_1481_VIS': 421, 'MVI_1609_VIS': 1336, 'MVI_1484_VIS': 388, 'MVI_1486_VIS': 975, 'MVI_1482_VIS': 358, 'MVI_1613_VIS': 883, 'MVI_1623_VIS': 444, 'MVI_1614_VIS': 980, 'MVI_1617_VIS': 965, 'MVI_1469_VIS': 804, 'MVI_1578_VIS': 497, 'MVI_1626_VIS': 807, 'MVI_1582_VIS': 912, 'MVI_1592_VIS': 492, 'MVI_1615_VIS': 523, 'MVI_1625_VIS': 1278, 'MVI_1448_VIS_Haze': 730, 'MVI_1646_VIS': 627, 'MVI_1612_VIS': 366, 'MVI_1478_VIS': 388, 'MVI_1452_VIS_Haze': 240, 'MVI_1644_VIS': 252, 'MVI_1451_VIS_Haze': 470, 'MVI_1610_VIS': 443, 'MVI_1474_VIS': 945, 'MVI_1479_VIS': 174, 'MVI_0797_VIS_OB': 155, 'MVI_0799_VIS_OB': 80, 'MVI_0790_VIS_OB': 53, 'MVI_0801_VIS_OB': 114, 'MVI_1532_NIR': 126, 'MVI_1538_NIR': 236, 'MVI_1526_NIR': 326, 'MVI_1528_NIR': 352, 'MVI_1468_NIR': 430, 'MVI_1545_NIR': 496, 'MVI_1527_NIR': 949, 'MVI_1520_NIR': 353, 'MVI_1521_NIR': 510, 'MVI_1530_NIR': 350, 'MVI_1529_NIR': 402, 'MVI_1523_NIR': 843, 'MVI_1463_NIR': 897, 'MVI_1524_NIR': 868, 'MVI_1548_NIR': 351, 'MVI_0895_NIR_Haze': 479, 'MVI_1539_NIR': 510, 'MVI_1525_NIR': 480, 'MVI_1550_NIR': 525, 'MVI_1541_NIR': 1121, 'MVI_1552_NIR': 324, 'MVI_1551_NIR': 657, 'MVI_1522_NIR': 366}

# %%
# generate numpy arrays with the objects' types

unique_videos_object_types_dict = {}
counters = {}
for key, value in unique_videos.items():
    unique_videos_object_types_dict[key] = np.zeros([value])
    counters[key] = 0

# pass the type by iterating once more. TODO: find a better way to avoid double iteration!
for i, line in enumerate(objects_onshore):
    line = line.split(',')
    video_name = line[0].split('_')[:-1]
    video_name = '_'.join(video_name)
    frame = int(line[0].split('_')[-1].replace('.jpg','').replace('frame',''))
    object_type = int(line[5])
    unique_videos_object_types_dict[video_name][counters[video_name]] = object_type
    counters[video_name] += 1

# %%
# try solution from : https://pstblog.com/2016/10/04/stacked-charts

# we have to use pandas here

#matplotlib.style.use('ggplot')


data = [[2000, 2000, 2000, 2001, 2001, 2001, 2002, 2002, 2002],
        ['Jan', 'Feb', 'Mar', 'Jan', 'Feb', 'Mar', 'Jan', 'Feb', 'Mar'],
        [1, 2, 3, 4, 5, 6, 7, 8, 9]]

rows = list(zip(data[0], data[1], data[2]))
headers = ['Year', 'Month', 'Value']
df = pd.DataFrame(rows, columns=headers)

df
# Out:
#    Year Month  Value
# 0  2000   Jan      1
# 1  2000   Feb      2
# 2  2000   Mar      3
# 3  2001   Jan      4
# 4  2001   Feb      5
# 5  2001   Mar      6
# 6  2002   Jan      7
# 7  2002   Feb      8
# 8  2002   Mar      9

# %%
fig, ax = plt.subplots(figsize=(10,7))  

months = df['Month'].drop_duplicates()
margin_bottom = np.zeros(len(df['Year'].drop_duplicates()))
colors = ["#006D2C", "#31A354","#74C476"]

for num, month in enumerate(months):
    values = list(df[df['Month'] == month].loc[:, 'Value'])

    df[df['Month'] == month].plot.bar(x='Year',y='Value', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[num], label=month)
    margin_bottom += values

plt.show()

# %%
# we need to count the instances of each object
unique_videos_object_counts = {}

for video_name, objects in unique_videos_object_types_dict.items():
    types, counts = generate_unique_values_histogram(objects)
    unique_videos_object_counts[video_name] = [types,counts]
    
print(unique_videos_object_counts)
# Out:
# {'MVI_1624_VIS': [array([1., 3.]), array([ 494, 1482])], 'MVI_1587_VIS': [array([ 3.,  5., 10.]), array([7800,  600,  458])], 'MVI_1584_VIS': [array([ 3.,  4.,  5., 10.]), array([5500,  550,  720,  550])], 'MVI_1645_VIS': [array([3.]), array([3210])], 'MVI_1619_VIS': [array([ 3., 10.]), array([2365,  473])], 'MVI_1622_VIS': [array([ 1.,  3., 10.]), array([249, 618, 236])], 'MVI_1620_VIS': [array([ 3., 10.]), array([2008, 1004])], 'MVI_1627_VIS': [array([3.]), array([4200])], 'MVI_1640_VIS': [array([ 3.,  4., 10.]), array([1826,  295,   62])], 'MVI_1583_VIS': [array([1., 3., 4.]), array([ 251, 2510,  425])], 'MVI_1481_VIS': [array([ 1.,  2.,  3., 10.]), array([1050,  409, 1286,  350])], 'MVI_1609_VIS': [array([1., 3., 6.]), array([1010, 4545, 3517])], 'MVI_1484_VIS': [array([1., 3.]), array([ 687, 2061])], 'MVI_1486_VIS': [array([ 1.,  2.,  3., 10.]), array([1052,  629, 4403,  629])], 'MVI_1482_VIS': [array([1., 3., 4.]), array([ 644, 1007,  809])], 'MVI_1613_VIS': [array([3., 4.]), array([6460,  113])], 'MVI_1623_VIS': [array([ 1.,  3., 10.]), array([ 522, 1528, 1044])], 'MVI_1614_VIS': [array([ 3.,  4., 10.]), array([3610,  582, 2765])], 'MVI_1617_VIS': [array([ 3., 10.]), array([5340,  600])], 'MVI_1469_VIS': [array([2., 3., 4., 9.]), array([ 600, 4200,  941,  206])], 'MVI_1578_VIS': [array([3.]), array([3535])], 'MVI_1626_VIS': [array([ 3., 10.]), array([2880, 2449])], 'MVI_1582_VIS': [array([1., 3.]), array([ 540, 5940])], 'MVI_1592_VIS': [array([1., 3., 6.]), array([ 491, 2347,  791])], 'MVI_1615_VIS': [array([ 3.,  7., 10.]), array([2711,  566,  566])], 'MVI_1625_VIS': [array([3.]), array([8111])], 'MVI_1448_VIS_Haze': [array([ 3.,  4., 10.]), array([3234, 1819,  390])], 'MVI_1646_VIS': [array([3.]), array([4533])], 'MVI_1612_VIS': [array([1., 3.]), array([ 165, 2349])], 'MVI_1478_VIS': [array([3., 4., 7.]), array([1539,  885,  477])], 'MVI_1452_VIS_Haze': [array([3., 7.]), array([1360,  340])], 'MVI_1644_VIS': [array([3.]), array([1764])], 'MVI_1451_VIS_Haze': [array([3., 4.]), array([2796,  474])], 'MVI_1610_VIS': [array([ 1.,  3.,  4.,  7., 10.]), array([ 543, 1086,  451,  543,  543])], 'MVI_1474_VIS': [array([ 1.,  2.,  3.,  9., 10.]), array([ 890, 1335, 3560,  444,  445])], 'MVI_1479_VIS': [array([3., 4.]), array([824, 447])]}

# %%
# print each video with the number of categories it has
for video_name, [types,counts] in unique_videos_object_counts.items():
    types_string = '['
    for type_entry in types:
        types_string += object_type_dict[type_entry]
        types_string += ','
    types_string += ']'
    print(video_name, ' has ', len(types), ' different object types: ', types_string)
# Out:
# MVI_1624_VIS  has  2  different object types:  [Ferry,Vessel/ship,]
# MVI_1587_VIS  has  3  different object types:  [Vessel/ship,Boat,Other,]
# MVI_1584_VIS  has  4  different object types:  [Vessel/ship,Speed boat,Boat,Other,]
# MVI_1645_VIS  has  1  different object types:  [Vessel/ship,]
# MVI_1619_VIS  has  2  different object types:  [Vessel/ship,Other,]
# MVI_1622_VIS  has  3  different object types:  [Ferry,Vessel/ship,Other,]
# MVI_1620_VIS  has  2  different object types:  [Vessel/ship,Other,]
# MVI_1627_VIS  has  1  different object types:  [Vessel/ship,]
# MVI_1640_VIS  has  3  different object types:  [Vessel/ship,Speed boat,Other,]
# MVI_1583_VIS  has  3  different object types:  [Ferry,Vessel/ship,Speed boat,]
# MVI_1481_VIS  has  4  different object types:  [Ferry,Buoy,Vessel/ship,Other,]
# MVI_1609_VIS  has  3  different object types:  [Ferry,Vessel/ship,Kayak,]
# MVI_1484_VIS  has  2  different object types:  [Ferry,Vessel/ship,]
# MVI_1486_VIS  has  4  different object types:  [Ferry,Buoy,Vessel/ship,Other,]
# MVI_1482_VIS  has  3  different object types:  [Ferry,Vessel/ship,Speed boat,]
# MVI_1613_VIS  has  2  different object types:  [Vessel/ship,Speed boat,]
# MVI_1623_VIS  has  3  different object types:  [Ferry,Vessel/ship,Other,]
# MVI_1614_VIS  has  3  different object types:  [Vessel/ship,Speed boat,Other,]
# MVI_1617_VIS  has  2  different object types:  [Vessel/ship,Other,]
# MVI_1469_VIS  has  4  different object types:  [Buoy,Vessel/ship,Speed boat,Flying bid/plane,]
# MVI_1578_VIS  has  1  different object types:  [Vessel/ship,]
# MVI_1626_VIS  has  2  different object types:  [Vessel/ship,Other,]
# MVI_1582_VIS  has  2  different object types:  [Ferry,Vessel/ship,]
# MVI_1592_VIS  has  3  different object types:  [Ferry,Vessel/ship,Kayak,]
# MVI_1615_VIS  has  3  different object types:  [Vessel/ship,Sail boat,Other,]
# MVI_1625_VIS  has  1  different object types:  [Vessel/ship,]
# MVI_1448_VIS_Haze  has  3  different object types:  [Vessel/ship,Speed boat,Other,]
# MVI_1646_VIS  has  1  different object types:  [Vessel/ship,]
# MVI_1612_VIS  has  2  different object types:  [Ferry,Vessel/ship,]
# MVI_1478_VIS  has  3  different object types:  [Vessel/ship,Speed boat,Sail boat,]
# MVI_1452_VIS_Haze  has  2  different object types:  [Vessel/ship,Sail boat,]
# MVI_1644_VIS  has  1  different object types:  [Vessel/ship,]
# MVI_1451_VIS_Haze  has  2  different object types:  [Vessel/ship,Speed boat,]
# MVI_1610_VIS  has  5  different object types:  [Ferry,Vessel/ship,Speed boat,Sail boat,Other,]
# MVI_1474_VIS  has  5  different object types:  [Ferry,Buoy,Vessel/ship,Flying bid/plane,Other,]
# MVI_1479_VIS  has  2  different object types:  [Vessel/ship,Speed boat,]

# %%
# add missing object type entries with zero count. This is required for the plot following.
# this is quite a hack TODO: maybe improve?
for video_name, [types,counts] in unique_videos_object_counts.items():
    types_full = np.arange(1, len(object_type_dict) + 1, dtype=int)
    counts_full = np.zeros([len(object_type_dict)])
    
    for i, type_entry in enumerate(types):
        counts_full[int(type_entry-1)] = counts[i]
        
    unique_videos_object_counts[video_name] = [types_full, counts_full]

# %%
# lets do it for the objects' types and create a nice graph!

# generate data in the form:
# [[video_name],[object type],[object type count]]

data = [[],[],[]]

for video_name, list_of_counts in unique_videos_object_counts.items():
    [types, counts] = list_of_counts
    for i in range(len(types)):
        data[0].append(video_name)
        data[1].append(object_type_dict[types[i]])
        data[2].append(counts[i])

rows = list(zip(data[0], data[1], data[2]))
headers = ['Video', 'Object type', 'Count']
df = pd.DataFrame(rows, columns=headers)

df
# Out:
#             Video       Object type   Count
# 0    MVI_1624_VIS             Ferry   494.0
# 1    MVI_1624_VIS              Buoy     0.0
# 2    MVI_1624_VIS       Vessel/ship  1482.0
# 3    MVI_1624_VIS        Speed boat     0.0
# 4    MVI_1624_VIS              Boat     0.0
# 5    MVI_1624_VIS             Kayak     0.0
# 6    MVI_1624_VIS         Sail boat     0.0
# 7    MVI_1624_VIS   Swimming person     0.0
# 8    MVI_1624_VIS  Flying bid/plane     0.0
# 9    MVI_1624_VIS             Other     0.0
# 10   MVI_1587_VIS             Ferry     0.0
# 11   MVI_1587_VIS              Buoy     0.0
# 12   MVI_1587_VIS       Vessel/ship  7800.0
# 13   MVI_1587_VIS        Speed boat     0.0
# 14   MVI_1587_VIS              Boat   600.0
# 15   MVI_1587_VIS             Kayak     0.0
# 16   MVI_1587_VIS         Sail boat     0.0
# 17   MVI_1587_VIS   Swimming person     0.0
# 18   MVI_1587_VIS  Flying bid/plane     0.0
# 19   MVI_1587_VIS             Other   458.0
# 20   MVI_1584_VIS             Ferry     0.0
# 21   MVI_1584_VIS              Buoy     0.0
# 22   MVI_1584_VIS       Vessel/ship  5500.0
# 23   MVI_1584_VIS        Speed boat   550.0
# 24   MVI_1584_VIS              Boat   720.0
# 25   MVI_1584_VIS             Kayak     0.0
# 26   MVI_1584_VIS         Sail boat     0.0
# 27   MVI_1584_VIS   Swimming person     0.0
# 28   MVI_1584_VIS  Flying bid/plane     0.0
# 29   MVI_1584_VIS             Other   550.0
# ..            ...               ...     ...
# 330  MVI_1610_VIS             Ferry   543.0
# 331  MVI_1610_VIS              Buoy     0.0
# 332  MVI_1610_VIS       Vessel/ship  1086.0
# 333  MVI_1610_VIS        Speed boat   451.0
# 334  MVI_1610_VIS              Boat     0.0
# 335  MVI_1610_VIS             Kayak     0.0
# 336  MVI_1610_VIS         Sail boat   543.0
# 337  MVI_1610_VIS   Swimming person     0.0
# 338  MVI_1610_VIS  Flying bid/plane     0.0
# 339  MVI_1610_VIS             Other   543.0
# 340  MVI_1474_VIS             Ferry   890.0
# 341  MVI_1474_VIS              Buoy  1335.0
# 342  MVI_1474_VIS       Vessel/ship  3560.0
# 343  MVI_1474_VIS        Speed boat     0.0
# 344  MVI_1474_VIS              Boat     0.0
# 345  MVI_1474_VIS             Kayak     0.0
# 346  MVI_1474_VIS         Sail boat     0.0
# 347  MVI_1474_VIS   Swimming person     0.0
# 348  MVI_1474_VIS  Flying bid/plane   444.0
# 349  MVI_1474_VIS             Other   445.0
# 350  MVI_1479_VIS             Ferry     0.0
# 351  MVI_1479_VIS              Buoy     0.0
# 352  MVI_1479_VIS       Vessel/ship   824.0
# 353  MVI_1479_VIS        Speed boat   447.0
# 354  MVI_1479_VIS              Boat     0.0
# 355  MVI_1479_VIS             Kayak     0.0
# 356  MVI_1479_VIS         Sail boat     0.0
# 357  MVI_1479_VIS   Swimming person     0.0
# 358  MVI_1479_VIS  Flying bid/plane     0.0
# 359  MVI_1479_VIS             Other     0.0
#
# [360 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(10,7))  

months = df['Object type'].drop_duplicates()
margin_bottom = np.zeros(len(df['Video'].drop_duplicates()))
colors = object_colours_list.copy()#["#006D2C", "#31A354","#74C476"]

for num, object_type in enumerate(months):
    values = list(df[df['Object type'] == object_type].loc[:, 'Count'])

    df[df['Object type'] == object_type].plot.bar(x='Video',y='Count', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[num], label=object_type)
    
    margin_bottom += values

plt.title('Object counts of onshore videos')
plt.tight_layout()
plt.savefig('objects_per_video_onshore.png', tight_layout=True, dpi=300)
plt.show()

# %% [markdown]
# Now lets pack the above in functions to use it multiple times

# %%
# first get all unique videos from the ground truth files and their 
# corresponding frame numbers. Create a dictionary the form: <video_name>:<frame_count>

def get_unique_videos_dict(objects_list):
    """
    Generates a dictionary of video keys and their object count as values in
    the form: <video_name>:<frame_count>
    
    Parameters
    ----------
    
    objects_list : list of csv entries. Each entry is of the form:
            [<video_name>_<frame_number>.jpg, 
            x_min, 
            y_min, 
            object width, 
            object height, 
            type of object, 
            distance of object, 
            type of motion of object]
            
            This file is generated from the ground truth files using another script.
    
    Returns
    -------
    
    unique_videos : a dictionary the form: <video_name>:<object_count>.
    """
    unique_videos = {}
    for line in objects_list:
        video_name = line.split(',')[0].split('_')[:-1]
        video_name = '_'.join(video_name)

        if video_name not in unique_videos:
            unique_videos[video_name] = 1
        else:
            unique_videos[video_name] += 1

    return unique_videos


# generate numpy arrays with the objects' types

def get_object_types_per_video_dictionary(unique_videos_dict, objects_list, object_attribute):
    """
    Generate dictionary with numpy arrays with the objects' types for each video.
    
    Parameters
    ----------
    
    unique_videos_dict : a dictionary the form: <video_name>:<object_count>.
    
    objects_list : list of csv entries. Each entry is of the form:
            [<video_name>_<frame_number>.jpg, 
            x_min, 
            y_min, 
            object width, 
            object height, 
            type of object, 
            distance of object, 
            type of motion of object]
            
            This file is generated from the ground truth files using another script.
            
    object_attribute : the attribute of object to export. String
            Valid values: ['Type','Motion','Distance']
            
    Returns
    -------
    
    unique_videos_object_types_dict : a dictionary the form: 
            <video_name>:<numpy array with each object type in every frame of video>.
    """
    
    attributes_dict = {'Type':5,'Distance':6,'Motion':7}
    attribute_position = attributes_dict[object_attribute]
    
    unique_videos_object_types_dict = {}
    counters = {}
    for key, value in unique_videos_dict.items():
        unique_videos_object_types_dict[key] = np.zeros([value])
        counters[key] = 0

    # pass the type by iterating once more. TODO: find a better way to avoid double iteration!
    # TODO: change here in order to switch to motion/distance with a parameter!
    for i, line in enumerate(objects_list):
        line = line.split(',')
        video_name = line[0].split('_')[:-1]
        video_name = '_'.join(video_name)
        frame = int(line[0].split('_')[-1].replace('.jpg','').replace('frame',''))
        object_type = int(line[attribute_position])  # HERE!!!! CHANGE
        unique_videos_object_types_dict[video_name][counters[video_name]] = object_type
        counters[video_name] += 1
        
    return unique_videos_object_types_dict

def get_video_object_count_dictionary(unique_videos_object_types_dict, normalized=False):
    """
    Generates the unique object types and their corresponding count for each video.
    
    Parameters
    ----------
    
    unique_videos_object_types_dict : a dictionary the form: 
            <video_name>:<numpy array with each object type in every frame of video>.
            
    normalized : normalize each video object counts to [0,1]? Boolean.
            Default: False
    
    Returns
    -------
    
    unique_videos_object_counts : a dictionary the form: 
            <video_name>:
            [numpy array of unique object types, numpy array of corresponding counts].
    
    """
    # we need to count the instances of each object
    unique_videos_object_counts = {}

    for video_name, objects in unique_videos_object_types_dict.items():
        types, counts = generate_unique_values_histogram(objects)
        if normalized:
            counts = counts / np.sum(counts)
        unique_videos_object_counts[video_name] = [types,counts]
    
        
    return unique_videos_object_counts
    

def print_video_objects(unique_videos_object_counts, label_dictionary):
    """
    Prints each video with the number of object categories it has and the 
    types of the categories.
    
    Parameters
    ----------
    
    unique_videos_object_counts : a dictionary the form: 
            <video_name>:
            [numpy array of unique object types, numpy array of corresponding counts].
            
    label_dictionary :  dictionary that hold the string values of the types.
    """
    # print each video with the number of categories it has
    for video_name, [types,counts] in unique_videos_object_counts.items():
        types_string = '['
        for type_entry in types:
            types_string += label_dictionary[type_entry]
            types_string += ','
        types_string += ']'
        print(video_name, ' has ', len(types), ' different entries: ', types_string)
    
    
def add_missing_types(unique_videos_object_counts, object_dictionary):
    """
    Add missing object type entries with zero count. This is required for the plot following.
    This is quite a hack TODO: maybe improve?
    
    Parameters
    ----------
    
    unique_videos_object_counts : a dictionary the form: 
            <video_name>:
            [numpy array of unique object types, numpy array of corresponding counts].
    
    Returns
    -------
    
    unique_videos_object_counts : a dictionary the form: 
            <video_name>:
            [numpy array of all object types (even with count zero), 
            numpy array of corresponding counts].
    """
    for video_name, [types,counts] in unique_videos_object_counts.items():
        types_full = np.arange(1, len(object_dictionary) + 1, dtype=int)
        counts_full = np.zeros([len(object_dictionary)])

        for i, type_entry in enumerate(types):
            counts_full[int(type_entry-1)] = counts[i]

        unique_videos_object_counts[video_name] = [types_full, counts_full]
        
    return unique_videos_object_counts

    
def convert_into_dataframe(unique_videos_object_counts, headers, object_dictionary):
    """
    Convert the dictionary into a dataframe.
    
    Parameters
    ----------
    
    unique_videos_object_counts : a dictionary the form: 
            <video_name>:
            [numpy array of unique object types, numpy array of corresponding counts].
            
    headers : list of the column header. Example: ['Video', 'Object type', 'Count']
    
    object_dictionary : dictionary mapping of object values to strings.
    
            
    Returns
    -------
    
    df : TODO
    """
    # generate data in the form:
    # [[video_name],[object type],[object type count]]
    data = [[],[],[]]

    for video_name, list_of_counts in unique_videos_object_counts.items():
        [types, counts] = list_of_counts
        for i in range(len(types)):
            data[0].append(video_name)
            data[1].append(object_dictionary[types[i]])
            data[2].append(counts[i])

    rows = list(zip(data[0], data[1], data[2]))
    headers = headers
    df = pd.DataFrame(rows, columns=headers)

    return df

def plot_df_bar_chart(df, column_values, title, filename=''):
    """
    TODO: write
    """
    fig, ax = plt.subplots(figsize=(10,7))  

    months = df[column_values[1]].drop_duplicates()
    margin_bottom = np.zeros(len(df[column_values[0]].drop_duplicates()))
    colors = object_colours_list.copy()#["#006D2C", "#31A354","#74C476"]
    
    for num, object_type in enumerate(months):
        values = list(df[df[column_values[1]] == object_type].loc[:, column_values[2]])

        df[df[column_values[1]] == object_type].plot.bar(x=column_values[0],y=column_values[2], ax=ax, stacked=True, 
                                        bottom = margin_bottom, color=colors[num], label=object_type)

        margin_bottom += values

    plt.title(title)
    plt.tight_layout()
    if filename != '':
        plt.savefig(filename, tight_layout=True, dpi=300)
    plt.show()

# %%
unique_videos = get_unique_videos_dict(test_objects)
unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                        test_objects, 'Type')
unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict)
print_video_objects(unique_videos_object_counts, object_type_dict)
unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_type_dict)
df = convert_into_dataframe(unique_videos_object_counts, ['Video', 'Object type', 'Count'], object_type_dict)

plot_df_bar_chart(df,['Video', 'Object type', 'Count'], 
                  'Object counts of test videos', os.path.join(FIGURE_SAVE_PATH, 'objects_per_video_test.png'))


# normalized version:
unique_videos = get_unique_videos_dict(test_objects)
unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                        test_objects, 'Type')
unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict, True)
#print_video_objects(unique_videos_object_counts)
unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_type_dict)
df = convert_into_dataframe(unique_videos_object_counts, ['Video', 'Object type', 'Count'], object_type_dict)

plot_df_bar_chart(df,['Video', 'Object type', 'Count'], 
                  'Normalized object counts of test videos', 
                  os.path.join(FIGURE_SAVE_PATH, 'objects_per_video_test_normalized.png'))
# Out:
# MVI_1624_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1587_VIS  has  3  different entries:  [Vessel/ship,Boat,Other,]
# MVI_1584_VIS  has  4  different entries:  [Vessel/ship,Speed boat,Boat,Other,]
# MVI_1645_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1619_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1622_VIS  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1620_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1627_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1640_VIS  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1583_VIS  has  3  different entries:  [Ferry,Vessel/ship,Speed boat,]
# MVI_1481_VIS  has  4  different entries:  [Ferry,Buoy,Vessel/ship,Other,]
# MVI_1609_VIS  has  3  different entries:  [Ferry,Vessel/ship,Kayak,]
# MVI_1484_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1486_VIS  has  4  different entries:  [Ferry,Buoy,Vessel/ship,Other,]
# MVI_1482_VIS  has  3  different entries:  [Ferry,Vessel/ship,Speed boat,]
# MVI_1613_VIS  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_1623_VIS  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1614_VIS  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1617_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1469_VIS  has  4  different entries:  [Buoy,Vessel/ship,Speed boat,Flying bid/plane,]
# MVI_1578_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1626_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1582_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1592_VIS  has  3  different entries:  [Ferry,Vessel/ship,Kayak,]
# MVI_1615_VIS  has  3  different entries:  [Vessel/ship,Sail boat,Other,]
# MVI_1625_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1448_VIS_Haze  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_1646_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1612_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1478_VIS  has  3  different entries:  [Vessel/ship,Speed boat,Sail boat,]
# MVI_1452_VIS_Haze  has  2  different entries:  [Vessel/ship,Sail boat,]
# MVI_1644_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1451_VIS_Haze  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_1610_VIS  has  5  different entries:  [Ferry,Vessel/ship,Speed boat,Sail boat,Other,]
# MVI_1474_VIS  has  5  different entries:  [Ferry,Buoy,Vessel/ship,Flying bid/plane,Other,]
# MVI_1479_VIS  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_0797_VIS_OB  has  1  different entries:  [Vessel/ship,]
# MVI_0799_VIS_OB  has  1  different entries:  [Vessel/ship,]
# MVI_0790_VIS_OB  has  1  different entries:  [Vessel/ship,]
# MVI_0801_VIS_OB  has  1  different entries:  [Vessel/ship,]
# MVI_1532_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1538_NIR  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1526_NIR  has  2  different entries:  [Vessel/ship,Sail boat,]
# MVI_1528_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1468_NIR  has  2  different entries:  [Buoy,Vessel/ship,]
# MVI_1545_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1527_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1520_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Sail boat,]
# MVI_1521_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1530_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1529_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1523_NIR  has  4  different entries:  [Ferry,Vessel/ship,Speed boat,Boat,]
# MVI_1463_NIR  has  3  different entries:  [Buoy,Vessel/ship,Flying bid/plane,]
# MVI_1524_NIR  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_1548_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_0895_NIR_Haze  has  3  different entries:  [Ferry,Vessel/ship,Boat,]
# MVI_1539_NIR  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1525_NIR  has  1  different entries:  [Vessel/ship,]
# MVI_1550_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1541_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1552_NIR  has  1  different entries:  [Vessel/ship,]
# MVI_1551_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1522_NIR  has  2  different entries:  [Vessel/ship,Other,]

# %%
unique_videos = get_unique_videos_dict(train_objects)
unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                        train_objects, 'Type')
unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict)
print_video_objects(unique_videos_object_counts, object_type_dict)
unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_type_dict)
df = convert_into_dataframe(unique_videos_object_counts, ['Video', 'Object type', 'Count'], object_type_dict)

plot_df_bar_chart(df,['Video', 'Object type', 'Count'], 
                  'Object counts of train videos', 
                  os.path.join(FIGURE_SAVE_PATH, 'objects_per_video_train.png'))


# normalized version
unique_videos = get_unique_videos_dict(train_objects)
unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                        train_objects, 'Type')
unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict, True)
#print_video_objects(unique_videos_object_counts)
unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_type_dict)
df = convert_into_dataframe(unique_videos_object_counts, ['Video', 'Object type', 'Count'], object_type_dict)

plot_df_bar_chart(df,['Video', 'Object type', 'Count'], 
                  'Normalized object counts of train videos', 
                  os.path.join(FIGURE_SAVE_PATH, 'objects_per_video_train_normalized.png'))
# Out:
# MVI_1624_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1587_VIS  has  3  different entries:  [Vessel/ship,Boat,Other,]
# MVI_1584_VIS  has  4  different entries:  [Vessel/ship,Speed boat,Boat,Other,]
# MVI_1645_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1619_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1622_VIS  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1620_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1627_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1640_VIS  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_1583_VIS  has  3  different entries:  [Ferry,Vessel/ship,Speed boat,]
# MVI_1481_VIS  has  4  different entries:  [Ferry,Buoy,Vessel/ship,Other,]
# MVI_1609_VIS  has  3  different entries:  [Ferry,Vessel/ship,Kayak,]
# MVI_1484_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1486_VIS  has  4  different entries:  [Ferry,Buoy,Vessel/ship,Other,]
# MVI_1482_VIS  has  3  different entries:  [Ferry,Vessel/ship,Speed boat,]
# MVI_1613_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1623_VIS  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1614_VIS  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1617_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1469_VIS  has  4  different entries:  [Buoy,Vessel/ship,Speed boat,Flying bid/plane,]
# MVI_1578_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1626_VIS  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1582_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1592_VIS  has  3  different entries:  [Ferry,Vessel/ship,Kayak,]
# MVI_1615_VIS  has  3  different entries:  [Vessel/ship,Sail boat,Other,]
# MVI_1625_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1448_VIS_Haze  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1646_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1612_VIS  has  2  different entries:  [Ferry,Vessel/ship,]
# MVI_1478_VIS  has  3  different entries:  [Vessel/ship,Speed boat,Sail boat,]
# MVI_1452_VIS_Haze  has  2  different entries:  [Vessel/ship,Sail boat,]
# MVI_1644_VIS  has  1  different entries:  [Vessel/ship,]
# MVI_1451_VIS_Haze  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_1610_VIS  has  5  different entries:  [Ferry,Vessel/ship,Speed boat,Sail boat,Other,]
# MVI_1474_VIS  has  5  different entries:  [Ferry,Buoy,Vessel/ship,Flying bid/plane,Other,]
# MVI_1479_VIS  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_0797_VIS_OB  has  1  different entries:  [Vessel/ship,]
# MVI_0799_VIS_OB  has  2  different entries:  [Vessel/ship,Speed boat,]
# MVI_0790_VIS_OB  has  3  different entries:  [Buoy,Vessel/ship,Boat,]
# MVI_0801_VIS_OB  has  2  different entries:  [Vessel/ship,Boat,]
# MVI_1532_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1538_NIR  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1526_NIR  has  3  different entries:  [Vessel/ship,Sail boat,Other,]
# MVI_1528_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1468_NIR  has  2  different entries:  [Buoy,Vessel/ship,]
# MVI_1545_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1527_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1520_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Sail boat,]
# MVI_1521_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1530_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1529_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1523_NIR  has  4  different entries:  [Ferry,Vessel/ship,Speed boat,Boat,]
# MVI_1463_NIR  has  3  different entries:  [Buoy,Vessel/ship,Flying bid/plane,]
# MVI_1524_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_1548_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]
# MVI_0895_NIR_Haze  has  1  different entries:  [Vessel/ship,]
# MVI_1539_NIR  has  3  different entries:  [Ferry,Vessel/ship,Other,]
# MVI_1525_NIR  has  1  different entries:  [Vessel/ship,]
# MVI_1550_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1541_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1552_NIR  has  1  different entries:  [Vessel/ship,]
# MVI_1551_NIR  has  2  different entries:  [Vessel/ship,Other,]
# MVI_1522_NIR  has  3  different entries:  [Vessel/ship,Speed boat,Other,]

# %% [markdown]
# # Now do the same for motion and distance

# %%
unique_videos = get_unique_videos_dict(train_objects)
unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                        train_objects, 'Motion')
unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict)
print_video_objects(unique_videos_object_counts, object_motion_dict)
unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_motion_dict)
df = convert_into_dataframe(unique_videos_object_counts, ['Video', 'Object motion', 'Count'], object_motion_dict)

plot_df_bar_chart(df,['Video', 'Object motion', 'Count'], 
                  'Object motion counts of train videos', 
                  os.path.join(FIGURE_SAVE_PATH, 'objects_motion_per_video_train.png'))

# normalized version:
unique_videos = get_unique_videos_dict(train_objects)
unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                        train_objects, 'Motion')
unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict, normalized=True)
#print_video_objects(unique_videos_object_counts)
unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_motion_dict)
df = convert_into_dataframe(unique_videos_object_counts, ['Video', 'Object motion', 'Count'], object_motion_dict)

plot_df_bar_chart(df,['Video', 'Object motion', 'Count'], 
                  'Normalized object motion counts of train videos', 
                  os.path.join(FIGURE_SAVE_PATH, 'objects_motion_per_video_train_normalized.png'))
# Out:
# MVI_1624_VIS  has  1  different entries:  [Stationary,]
# MVI_1587_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1584_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1645_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1619_VIS  has  1  different entries:  [Moving,]
# MVI_1622_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1620_VIS  has  1  different entries:  [Moving,]
# MVI_1627_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1640_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1583_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1481_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1609_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1484_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1486_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1482_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1613_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1623_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1614_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1617_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1469_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1578_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1626_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1582_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1592_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1615_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1625_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1448_VIS_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1646_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1612_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1478_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1452_VIS_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1644_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1451_VIS_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1610_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1474_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1479_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_0797_VIS_OB  has  2  different entries:  [Moving,Stationary,]
# MVI_0799_VIS_OB  has  2  different entries:  [Moving,Stationary,]
# MVI_0790_VIS_OB  has  2  different entries:  [Moving,Other,]
# MVI_0801_VIS_OB  has  1  different entries:  [Stationary,]
# MVI_1532_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1538_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1526_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1528_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1468_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1545_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1527_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1520_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1521_NIR  has  1  different entries:  [Moving,]
# MVI_1530_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1529_NIR  has  1  different entries:  [Moving,]
# MVI_1523_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1463_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1524_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1548_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_0895_NIR_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1539_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1525_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1550_NIR  has  1  different entries:  [Moving,]
# MVI_1541_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1552_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1551_NIR  has  1  different entries:  [Moving,]
# MVI_1522_NIR  has  2  different entries:  [Moving,Stationary,]

# %%
def create_nice_bar_plot(objects_data, 
                         object_dict,  
                         data_column='Motion',
                         dataframe_columns=['Video', 'Object motion', 'Count'],
                        fig_title='Object motion counts of onshore videos',
                        fig_filename='objects_motion_per_video_onshore.png',
                        norm_fig_title='Normalized object motion counts of onshore videos',
                        norm_fig_filename='objects_motion_per_video_onshore_normalized.png'):
    
    """
    TODO: write!!
    
    It was about time I did this function!!
    """
    
    unique_videos = get_unique_videos_dict(objects_data)
    unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                            objects_data, data_column)
    unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict)
    print_video_objects(unique_videos_object_counts, object_dict)
    unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_dict)
    df = convert_into_dataframe(unique_videos_object_counts, dataframe_columns, object_dict)

    plot_df_bar_chart(df,dataframe_columns, fig_title, fig_filename)

    # normalized version:
    unique_videos = get_unique_videos_dict(objects_data)
    unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                            objects_data, data_column)
    unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict, normalized=True)
    #print_video_objects(unique_videos_object_counts)
    unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_dict)
    df = convert_into_dataframe(unique_videos_object_counts, dataframe_columns, object_dict)

    plot_df_bar_chart(df,dataframe_columns, norm_fig_title, norm_fig_filename)

# %%
create_nice_bar_plot(test_objects, object_motion_dict, 'Motion', ['Video', 'Object motion', 'Count'],
                    'Object motion counts of test videos',
                    os.path.join(FIGURE_SAVE_PATH, 'objects_motion_per_video_test.png'),
                    'Normalized object motion counts of test videos',
                    os.path.join(FIGURE_SAVE_PATH, 'objects_motion_per_video_test_normalized.png'))
# Out:
# MVI_1624_VIS  has  1  different entries:  [Stationary,]
# MVI_1587_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1584_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1645_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1619_VIS  has  1  different entries:  [Moving,]
# MVI_1622_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1620_VIS  has  1  different entries:  [Moving,]
# MVI_1627_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1640_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1583_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1481_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1609_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1484_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1486_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1482_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1613_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1623_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1614_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1617_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1469_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1578_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1626_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1582_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1592_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1615_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1625_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1448_VIS_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1646_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1612_VIS  has  1  different entries:  [Moving,]
# MVI_1478_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1452_VIS_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1644_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1451_VIS_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1610_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1474_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_1479_VIS  has  2  different entries:  [Moving,Stationary,]
# MVI_0797_VIS_OB  has  2  different entries:  [Moving,Stationary,]
# MVI_0799_VIS_OB  has  1  different entries:  [Moving,]
# MVI_0790_VIS_OB  has  1  different entries:  [Stationary,]
# MVI_0801_VIS_OB  has  1  different entries:  [Stationary,]
# MVI_1532_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1538_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1526_NIR  has  1  different entries:  [Stationary,]
# MVI_1528_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1468_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1545_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1527_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1520_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1521_NIR  has  1  different entries:  [Moving,]
# MVI_1530_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1529_NIR  has  1  different entries:  [Moving,]
# MVI_1523_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1463_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1524_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1548_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_0895_NIR_Haze  has  2  different entries:  [Moving,Stationary,]
# MVI_1539_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1525_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1550_NIR  has  1  different entries:  [Moving,]
# MVI_1541_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1552_NIR  has  2  different entries:  [Moving,Stationary,]
# MVI_1551_NIR  has  1  different entries:  [Moving,]
# MVI_1522_NIR  has  1  different entries:  [Moving,]

# %%
create_nice_bar_plot(train_objects, object_distance_dict, 'Distance', ['Video', 'Object distance', 'Count'],
                    'Object distance counts of train videos',
                    os.path.join(FIGURE_SAVE_PATH, 'objects_distance_per_video_train.png'),
                    'Normalized object distance counts of train videos',
                    os.path.join(FIGURE_SAVE_PATH, 'objects_distance_per_video_train_normalized.png'))
# Out:
# MVI_1624_VIS  has  1  different entries:  [Far,]
# MVI_1587_VIS  has  2  different entries:  [Near,Far,]
# MVI_1584_VIS  has  1  different entries:  [Far,]
# MVI_1645_VIS  has  2  different entries:  [Near,Far,]
# MVI_1619_VIS  has  1  different entries:  [Far,]
# MVI_1622_VIS  has  2  different entries:  [Near,Far,]
# MVI_1620_VIS  has  1  different entries:  [Far,]
# MVI_1627_VIS  has  2  different entries:  [Near,Far,]
# MVI_1640_VIS  has  3  different entries:  [Near,Far,Other,]
# MVI_1583_VIS  has  1  different entries:  [Far,]
# MVI_1481_VIS  has  3  different entries:  [Near,Far,Other,]
# MVI_1609_VIS  has  2  different entries:  [Near,Far,]
# MVI_1484_VIS  has  1  different entries:  [Near,]
# MVI_1486_VIS  has  2  different entries:  [Near,Far,]
# MVI_1482_VIS  has  2  different entries:  [Near,Far,]
# MVI_1613_VIS  has  1  different entries:  [Far,]
# MVI_1623_VIS  has  1  different entries:  [Far,]
# MVI_1614_VIS  has  2  different entries:  [Near,Far,]
# MVI_1617_VIS  has  2  different entries:  [Far,Other,]
# MVI_1469_VIS  has  2  different entries:  [Near,Far,]
# MVI_1578_VIS  has  1  different entries:  [Far,]
# MVI_1626_VIS  has  2  different entries:  [Far,Other,]
# MVI_1582_VIS  has  2  different entries:  [Near,Far,]
# MVI_1592_VIS  has  3  different entries:  [Near,Far,Other,]
# MVI_1615_VIS  has  1  different entries:  [Far,]
# MVI_1625_VIS  has  2  different entries:  [Near,Far,]
# MVI_1448_VIS_Haze  has  1  different entries:  [Far,]
# MVI_1646_VIS  has  2  different entries:  [Near,Far,]
# MVI_1612_VIS  has  1  different entries:  [Far,]
# MVI_1478_VIS  has  2  different entries:  [Near,Far,]
# MVI_1452_VIS_Haze  has  3  different entries:  [Near,Far,Other,]
# MVI_1644_VIS  has  2  different entries:  [Near,Far,]
# MVI_1451_VIS_Haze  has  2  different entries:  [Near,Far,]
# MVI_1610_VIS  has  1  different entries:  [Far,]
# MVI_1474_VIS  has  2  different entries:  [Near,Far,]
# MVI_1479_VIS  has  2  different entries:  [Near,Far,]
# MVI_0797_VIS_OB  has  2  different entries:  [Far,Other,]
# MVI_0799_VIS_OB  has  2  different entries:  [Far,Other,]
# MVI_0790_VIS_OB  has  2  different entries:  [Near,Far,]
# MVI_0801_VIS_OB  has  1  different entries:  [Far,]
# MVI_1532_NIR  has  2  different entries:  [Far,Other,]
# MVI_1538_NIR  has  2  different entries:  [Far,Other,]
# MVI_1526_NIR  has  2  different entries:  [Far,Other,]
# MVI_1528_NIR  has  2  different entries:  [Far,Other,]
# MVI_1468_NIR  has  2  different entries:  [Near,Far,]
# MVI_1545_NIR  has  3  different entries:  [Near,Far,Other,]
# MVI_1527_NIR  has  1  different entries:  [Far,]
# MVI_1520_NIR  has  2  different entries:  [Far,Other,]
# MVI_1521_NIR  has  1  different entries:  [Far,]
# MVI_1530_NIR  has  2  different entries:  [Far,Other,]
# MVI_1529_NIR  has  1  different entries:  [Far,]
# MVI_1523_NIR  has  2  different entries:  [Far,Other,]
# MVI_1463_NIR  has  2  different entries:  [Near,Far,]
# MVI_1524_NIR  has  2  different entries:  [Far,Other,]
# MVI_1548_NIR  has  1  different entries:  [Far,]
# MVI_0895_NIR_Haze  has  2  different entries:  [Near,Far,]
# MVI_1539_NIR  has  2  different entries:  [Far,Other,]
# MVI_1525_NIR  has  2  different entries:  [Far,Other,]
# MVI_1550_NIR  has  1  different entries:  [Far,]
# MVI_1541_NIR  has  2  different entries:  [Far,Other,]
# MVI_1552_NIR  has  2  different entries:  [Near,Far,]
# MVI_1551_NIR  has  1  different entries:  [Far,]
# MVI_1522_NIR  has  2  different entries:  [Far,Other,]

# %%
create_nice_bar_plot(test_objects, object_distance_dict, 'Distance', ['Video', 'Object distance', 'Count'],
                    'Object distance counts of test videos',
                    os.path.join(FIGURE_SAVE_PATH, 'objects_distance_per_video_test.png'),
                    'Normalized object distance counts of test videos',
                    os.path.join(FIGURE_SAVE_PATH, 'objects_distance_per_video_test_normalized.png'))
# Out:
# MVI_1624_VIS  has  1  different entries:  [Far,]
# MVI_1587_VIS  has  2  different entries:  [Near,Far,]
# MVI_1584_VIS  has  1  different entries:  [Far,]
# MVI_1645_VIS  has  2  different entries:  [Near,Far,]
# MVI_1619_VIS  has  1  different entries:  [Far,]
# MVI_1622_VIS  has  2  different entries:  [Near,Far,]
# MVI_1620_VIS  has  1  different entries:  [Far,]
# MVI_1627_VIS  has  2  different entries:  [Near,Far,]
# MVI_1640_VIS  has  3  different entries:  [Near,Far,Other,]
# MVI_1583_VIS  has  1  different entries:  [Far,]
# MVI_1481_VIS  has  3  different entries:  [Near,Far,Other,]
# MVI_1609_VIS  has  2  different entries:  [Near,Far,]
# MVI_1484_VIS  has  1  different entries:  [Near,]
# MVI_1486_VIS  has  2  different entries:  [Near,Far,]
# MVI_1482_VIS  has  1  different entries:  [Near,]
# MVI_1613_VIS  has  1  different entries:  [Far,]
# MVI_1623_VIS  has  1  different entries:  [Far,]
# MVI_1614_VIS  has  2  different entries:  [Near,Far,]
# MVI_1617_VIS  has  2  different entries:  [Far,Other,]
# MVI_1469_VIS  has  2  different entries:  [Near,Far,]
# MVI_1578_VIS  has  1  different entries:  [Far,]
# MVI_1626_VIS  has  2  different entries:  [Far,Other,]
# MVI_1582_VIS  has  2  different entries:  [Near,Far,]
# MVI_1592_VIS  has  3  different entries:  [Near,Far,Other,]
# MVI_1615_VIS  has  1  different entries:  [Far,]
# MVI_1625_VIS  has  2  different entries:  [Near,Far,]
# MVI_1448_VIS_Haze  has  1  different entries:  [Far,]
# MVI_1646_VIS  has  2  different entries:  [Near,Far,]
# MVI_1612_VIS  has  1  different entries:  [Far,]
# MVI_1478_VIS  has  2  different entries:  [Near,Far,]
# MVI_1452_VIS_Haze  has  3  different entries:  [Near,Far,Other,]
# MVI_1644_VIS  has  2  different entries:  [Near,Far,]
# MVI_1451_VIS_Haze  has  2  different entries:  [Near,Far,]
# MVI_1610_VIS  has  1  different entries:  [Far,]
# MVI_1474_VIS  has  2  different entries:  [Near,Far,]
# MVI_1479_VIS  has  2  different entries:  [Near,Far,]
# MVI_0797_VIS_OB  has  2  different entries:  [Far,Other,]
# MVI_0799_VIS_OB  has  1  different entries:  [Far,]
# MVI_0790_VIS_OB  has  1  different entries:  [Near,]
# MVI_0801_VIS_OB  has  1  different entries:  [Far,]
# MVI_1532_NIR  has  2  different entries:  [Far,Other,]
# MVI_1538_NIR  has  2  different entries:  [Far,Other,]
# MVI_1526_NIR  has  2  different entries:  [Far,Other,]
# MVI_1528_NIR  has  2  different entries:  [Far,Other,]
# MVI_1468_NIR  has  2  different entries:  [Near,Far,]
# MVI_1545_NIR  has  3  different entries:  [Near,Far,Other,]
# MVI_1527_NIR  has  1  different entries:  [Far,]
# MVI_1520_NIR  has  2  different entries:  [Far,Other,]
# MVI_1521_NIR  has  1  different entries:  [Far,]
# MVI_1530_NIR  has  2  different entries:  [Far,Other,]
# MVI_1529_NIR  has  1  different entries:  [Far,]
# MVI_1523_NIR  has  1  different entries:  [Far,]
# MVI_1463_NIR  has  2  different entries:  [Near,Far,]
# MVI_1524_NIR  has  2  different entries:  [Far,Other,]
# MVI_1548_NIR  has  1  different entries:  [Far,]
# MVI_0895_NIR_Haze  has  2  different entries:  [Near,Far,]
# MVI_1539_NIR  has  2  different entries:  [Far,Other,]
# MVI_1525_NIR  has  2  different entries:  [Far,Other,]
# MVI_1550_NIR  has  1  different entries:  [Far,]
# MVI_1541_NIR  has  2  different entries:  [Far,Other,]
# MVI_1552_NIR  has  2  different entries:  [Near,Far,]
# MVI_1551_NIR  has  1  different entries:  [Far,]
# MVI_1522_NIR  has  1  different entries:  [Far,]

# %% [markdown]
# # Statistics of objects and the number of videos they appear
#
# In this statistic we will count the number of videos each object appears. Each video will be counted if the object appears in at least one frame.

# %%
# TODO: later

# %% [markdown]
# # Generate Heatmaps

# %%
def get_dataframe(objects_data, 
                         object_dict,  
                         data_column='Type',
                         dataframe_columns=['Video', 'Object type', 'Count']):
    
    """
    TODO: write!!
    
    It was about time I did this function!!
    """
    
    unique_videos = get_unique_videos_dict(objects_data)
    unique_videos_object_types_dict = get_object_types_per_video_dictionary(unique_videos, 
                                                                            objects_data, data_column)
    unique_videos_object_counts = get_video_object_count_dictionary(unique_videos_object_types_dict)
    #print_video_objects(unique_videos_object_counts, object_dict)
    unique_videos_object_counts = add_missing_types(unique_videos_object_counts, object_dict)
    df = convert_into_dataframe(unique_videos_object_counts, dataframe_columns, object_dict)

    return df

# %%
import seaborn as sns

df = get_dataframe(train_objects, 
                   object_type_dict, 
                   'Type', 
                   ['Video', 'Object type', 'Count'])
                   
#print(df)
df = df.pivot('Object type','Video', 'Count')
fig = plt.figure()
fig.set_size_inches(15.5, 8.5)
#plt.set_size_inches(38.5, 10.5)

ax = sns.heatmap(df, linewidth=0.01, cmap='Blues',xticklabels=True, yticklabels=True)
plt.title('Heatmap of object types in train dataset')
plt.tight_layout()
#ax.set_yticklabels(ax.get_yticklabels(), rotation =0)
#ax.set_xticklabels(ax.get_yticklabels(), rotation =90)
plt.savefig(os.path.join(FIGURE_SAVE_PATH ,'heatmap_objects_train.png'), tight_layout=True, dpi=300)
plt.show()

# %%
df = get_dataframe(test_objects, 
                   object_type_dict, 
                   'Type', 
                   ['Video', 'Object type', 'Count'])
                   
#print(df)
df = df.pivot('Object type','Video', 'Count')
fig = plt.figure()
fig.set_size_inches(15.5, 8.5)
#plt.set_size_inches(38.5, 10.5)

ax = sns.heatmap(df, linewidth=0.01, cmap='Blues',xticklabels=True, yticklabels=True)
plt.title('Heatmap of object types in test dataset')
plt.tight_layout()
#ax.set_yticklabels(ax.get_yticklabels(), rotation =0)
#ax.set_xticklabels(ax.get_yticklabels(), rotation =90)
plt.savefig(os.path.join(FIGURE_SAVE_PATH ,'heatmap_objects_test.png'), tight_layout=True, dpi=300)
plt.show()
